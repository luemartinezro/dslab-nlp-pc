# %% [markdown]
# # Benchmark: Compare experiments and decide the champion architecture

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datetime import datetime
import os
import pandas as pd
from sklearn.metrics import f1_score
from src import models, utils

# %% [markdown]
# # Parameters

# %%
VERSION_ID = '202602'  # model_version_id
SCORE = "F1"

# Paths
path_interim = os.path.join("data", "interim")
path_experiment1 =  os.path.join(path_interim, "exp01_hpt_nb")
path_experiment2 =  os.path.join(path_interim, "exp02_hpt_gbt")
path_model_prod = os.path.join("models", "prod")
path_model_arch = os.path.join("models", "archive")

# Input
file_train = "train.csv"
file_test = "test.csv"

# %%
if not os.path.exists(path_model_prod):
    print(f"Creating the folder: {path_model_prod}")
    os.mkdir(path_model_prod)
if not os.path.exists(path_model_arch):
    print(f"Creating the folder: {path_model_arch}")
    os.mkdir(path_model_arch)

# %% [markdown]
# # Load data

# %% [markdown]
# ## Train/Test Subsets

# %%
path_data_train = os.path.join(path_interim, file_train)

df_train = pd.read_csv(path_data_train)
df_train.head(2)
# Out:
#                                               x_text  y_is_nf
# 0  Poder crear cualquier mérito y asociarlo a mi ...        0
# 1  Como usuario autenticado quiero indicar que to...        0

# %%
path_data_test = os.path.join(path_interim, file_test)

df_test = pd.read_csv(path_data_test)
df_test.head(2)
# Out:
#                                               x_text  y_is_nf
# 0  Proporcionará un tablón de eventos dentro de l...        0
# 1                              Añadir revista nueva.        0

# %% [markdown]
# ## Experiments results

# %%
df_cv_summary_exp1 = pd.read_csv(
    os.path.join(path_experiment1,"df_exp_summary.csv")
)
df_cv_summary_exp1.head(2)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.328690      0.069224         0.118635        0.007134
# 1       0.264642      0.011554         0.114961        0.007888
#
#    param_fte__max_df  param_fte__max_features  param_fte__min_df  \
# 0                0.1                       50                  1
# 1                0.1                       50                  3
#
#                                               params  split0_test_score  \
# 0  {'fte__max_df': 0.1, 'fte__max_features': 50, ...           0.542373
# 1  {'fte__max_df': 0.1, 'fte__max_features': 50, ...           0.571429
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.597015           0.411765         0.517051        0.077719
# 1           0.597015           0.411765         0.526736        0.081965
#
#    rank_test_score experiment_id
# 0               41  exp01_hpt_nb
# 1               40  exp01_hpt_nb

# %%
df_cv_summary_exp2 = pd.read_csv(
     os.path.join(path_experiment2,"df_exp_summary.csv")
)
df_cv_summary_exp2.head(2)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.769881      0.160945         0.081500        0.020005
# 1       1.714828      0.063025         0.065027        0.004123
#
#    param_clf__max_depth  param_fte__max_df  param_fte__max_features  \
# 0                     2                0.1                       10
# 1                     2                0.1                       10
#
#    param_fte__min_df                                             params  \
# 0                  1  {'clf__max_depth': 2, 'fte__max_df': 0.1, 'fte...
# 1                  3  {'clf__max_depth': 2, 'fte__max_df': 0.1, 'fte...
#
#    split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 0                0.2                0.0           0.153846         0.117949
# 1                0.2                0.0           0.000000         0.066667
#
#    std_test_score  rank_test_score  experiment_id
# 0        0.085504              169  exp02_hpt_gbt
# 1        0.094281              173  exp02_hpt_gbt

# %% [markdown]
# # Benchmark

# %%
df_cv_summary_exp1.sort_values(ascending=True, by="rank_test_score").head(5)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 26       0.223155      0.010556         0.111054        0.006084
# 29       0.243945      0.016002         0.142250        0.035356
# 23       0.269929      0.044994         0.120188        0.005865
# 38       0.267924      0.063077         0.117569        0.002215
# 41       0.237565      0.024427         0.112443        0.003864
#
#     param_fte__max_df  param_fte__max_features  param_fte__min_df  \
# 26               0.25                     1000                  5
# 29               0.25                     2000                  5
# 23               0.25                      500                  5
# 38               0.50                      500                  5
# 41               0.50                     1000                  5
#
#                                                params  split0_test_score  \
# 26  {'fte__max_df': 0.25, 'fte__max_features': 100...               0.68
# 29  {'fte__max_df': 0.25, 'fte__max_features': 200...               0.68
# 23  {'fte__max_df': 0.25, 'fte__max_features': 500...               0.68
# 38  {'fte__max_df': 0.5, 'fte__max_features': 500,...               0.68
# 41  {'fte__max_df': 0.5, 'fte__max_features': 1000...               0.68
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 26           0.754717           0.808511         0.747743        0.052696
# 29           0.754717           0.808511         0.747743        0.052696
# 23           0.754717           0.808511         0.747743        0.052696
# 38           0.754717           0.808511         0.747743        0.052696
# 41           0.754717           0.808511         0.747743        0.052696
#
#     rank_test_score experiment_id
# 26                1  exp01_hpt_nb
# 29                1  exp01_hpt_nb
# 23                1  exp01_hpt_nb
# 38                1  exp01_hpt_nb
# 41                1  exp01_hpt_nb

# %%
df_cv_summary_exp2.sort_values(ascending=True, by="rank_test_score").head(5)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 23       1.895222      0.158946         0.066013        0.004588
# 38       2.184465      0.039063         0.068256        0.007357
# 41       2.073582      0.070645         0.066723        0.004138
# 26       2.044204      0.234791         0.069008        0.004804
# 24       2.134710      0.029400         0.062239        0.000638
#
#     param_clf__max_depth  param_fte__max_df  param_fte__max_features  \
# 23                     2               0.25                      100
# 38                     2               0.50                      100
# 41                     2               0.50                      150
# 26                     2               0.25                      150
# 24                     2               0.25                      150
#
#     param_fte__min_df                                             params  \
# 23                  5  {'clf__max_depth': 2, 'fte__max_df': 0.25, 'ft...
# 38                  5  {'clf__max_depth': 2, 'fte__max_df': 0.5, 'fte...
# 41                  5  {'clf__max_depth': 2, 'fte__max_df': 0.5, 'fte...
# 26                  5  {'clf__max_depth': 2, 'fte__max_df': 0.25, 'ft...
# 24                  1  {'clf__max_depth': 2, 'fte__max_df': 0.25, 'ft...
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 23           0.625000           0.800000           0.585366         0.670122
# 38           0.625000           0.800000           0.585366         0.670122
# 41           0.600000           0.716981           0.634146         0.650376
# 26           0.600000           0.716981           0.634146         0.650376
# 24           0.583333           0.705882           0.651163         0.646793
#
#     std_test_score  rank_test_score  experiment_id
# 23        0.093252                1  exp02_hpt_gbt
# 38        0.093252                1  exp02_hpt_gbt
# 41        0.049117                3  exp02_hpt_gbt
# 26        0.049117                3  exp02_hpt_gbt
# 24        0.050126                5  exp02_hpt_gbt

# %%
# review params first model
print(df_cv_summary_exp2.params[0])
# Out:
# {'clf__max_depth': 2, 'fte__max_df': 0.1, 'fte__max_features': 10, 'fte__min_df': 1}

# %% [markdown]
# # Champion model

# %%
df_cv_summary_exp1.loc[
    df_cv_summary_exp1['rank_test_score'] == 1, [
        "mean_test_score", "std_test_score",
        "param_fte__max_df","param_fte__max_features",	"param_fte__min_df"]  # set the params of your champion model
]   # at a tie, you can get the model with : lowest std_test_score and the most simple one
# Out:
#     mean_test_score  std_test_score  param_fte__max_df  \
# 23         0.747743        0.052696               0.25
# 26         0.747743        0.052696               0.25
# 29         0.747743        0.052696               0.25
# 38         0.747743        0.052696               0.50
# 41         0.747743        0.052696               0.50
# 44         0.747743        0.052696               0.50
#
#     param_fte__max_features  param_fte__min_df
# 23                      500                  5
# 26                     1000                  5
# 29                     2000                  5
# 38                      500                  5
# 41                     1000                  5
# 44                     2000                  5

# %% [markdown]
# Go to src/models.py and implement get_model()
#
#
# ```python
# def get_model(
#     # your Hiperparameters:
#     min_df: int = 3,
#     max_df: float = 0.5,
#     ...
# ):
#     """
#     Builds and returns a scikit-learn Pipeline for Spanish text classification
#
#     Args:
#         min_df (int): Minimum document frequency for vectorizer.
#         max_df (float): Maximum document frequency for vectorizer.
#         max_features (int, optional): Maximum number of features to include.
#
#     Returns:
#         sklearn.pipeline.Pipeline: A pipeline with vectorizer and a classifier.
#     """
#
#
#     logging.info("Building pipeline...")
#
#     # Your vectorization strategy
#     dtm_transformer = XXXVectorizer(
#         ...
#     )
#
#     # Your model
#     clf = ...
#
#
#     # Champion pipeline architecture
#     skl_pl = Pipeline([
#         ('fte', dtm_transformer),
#         ('clf', clf)
#     ])
#
#     return skl_pl
# ```

# %%
from src.models import get_model
from sklearn.metrics import accuracy_score
# Champion model
get_model()
# Out:
# 2026-03-18 11:16:36 [INFO] Building pipeline...
# Pipeline(steps=[('fte',
#                  CountVectorizer(binary=True, strip_accents='ascii',
#                                  tokenizer=<function tokenizer_stemmer_es at 0x7325618b8400>)),
#                 ('clf',
#                  GradientBoostingClassifier(n_estimators=2000, random_state=123,
#                                             validation_fraction=0.2))])

# %%
# Testing champion model with simple accuracy measure

X_train = df_train['x_text']
y_train = df_train['y_is_nf']
X_test = df_test['x_text']
y_test = df_test['y_is_nf']



# Fit champion model on the training data
model = get_model()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Test the results in testing data

test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test accuracy: {test_accuracy:.4f}")
# Out:
# 2026-03-18 11:18:03 [INFO] Building pipeline...
# /home/estebanm/Escritorio/Master/pc4_nlp/dslab-nlp-pc/.venv/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Test accuracy: 0.8974
