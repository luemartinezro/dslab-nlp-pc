# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ![estado-final](outputs/estado-final.png)

# %%
from src import utils

result = utils.check_project_artifacts(base_dir=".", date_tag="202602")
print(result.ok)
print("Missing dirs:", result.missing_dirs)
print("Missing files:", result.missing_files)
# Out:
# False
# Missing dirs: (PosixPath('/home/estebanm/Escritorio/Master/pc4_nlp/dslab-nlp-pc/models/archive/202602'),)
# Missing files: (PosixPath('/home/estebanm/Escritorio/Master/pc4_nlp/dslab-nlp-pc/data/processed/scoring_202602.csv'), PosixPath('/home/estebanm/Escritorio/Master/pc4_nlp/dslab-nlp-pc/models/archive/202602/metadata.pkl'), PosixPath('/home/estebanm/Escritorio/Master/pc4_nlp/dslab-nlp-pc/models/archive/202602/model.pkl'), PosixPath('/home/estebanm/Escritorio/Master/pc4_nlp/dslab-nlp-pc/models/prod/metadata.pkl'), PosixPath('/home/estebanm/Escritorio/Master/pc4_nlp/dslab-nlp-pc/models/prod/model.pkl'))
