# %% [markdown]
# # Check Setup

# %%
import sys
import os
import numpy as np
import pandas as pd
import sklearn
import spacy
import nltk
import langdetect

# %%
print(f"{sys.version=}")  # Py version of the current environment
print(f"{os.getcwd()=}") ## this should be project's root folder
# Out:
# sys.version='3.12.3 (main, Mar  3 2026, 12:15:18) [GCC 13.3.0]'
# os.getcwd()='/home/estebanm/Escritorio/Master/pc4_nlp/dslab-nlp-pc'

# %%
print(f"{sklearn.__version__=}")
print(f"{nltk.__version__=}")
print(f"{pd.__version__=}")
print(f"{spacy.__version__=}")
# Out:
# sklearn.__version__='1.6.1'
# nltk.__version__='3.9.1'
# pd.__version__='2.2.2'
# spacy.__version__='3.8.7'

# %%
# Paths: Data
path_raw = os.path.join("data", "raw")
path_interim = os.path.join("data", "interim")


print(f"{os.path.isdir(path_raw)=}")
print(f"{os.path.isdir(path_interim)=}")
# Out:
# os.path.isdir(path_raw)=True
# os.path.isdir(path_interim)=True

# %%
# Input
file_input = "New%20Spanish%20Academic%20Dataset.csv"


path_data_raw = os.path.join(path_raw, file_input)
print(f"{os.path.exists(path_raw)=}")
# Out:
# os.path.exists(path_raw)=True

# %%
# Paths: Models
path_models_prod = os.path.join("models", "prod")
path_models_archive = os.path.join("models", "archive")


print(f"{os.path.isdir(path_models_prod)=}")
print(f"{os.path.isdir(path_models_archive)=}")
# Out:
# os.path.isdir(path_models_prod)=True
# os.path.isdir(path_models_archive)=True
